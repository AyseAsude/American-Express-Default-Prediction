# %%
import numpy as np
import pandas as pd
import gc

# %%
train = pd.read_feather('./train_data.ftr')
catg = ['B_30', 'B_31', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68']
cont_features = sorted([f for f in train.columns if f not in catg + ["customed_ID", 'target', 'S_2']])

# %% [markdown]
# # Feature Engineering
# Common steps to follow:
# - ...
#
# Here are the strategies to try for each model:
# - Aggregate features for every customer
# - Use rows as they are

# %%
def aggregate_features(data, categorical_cols, numerical_cols):
    
    categorical_cols = [c for c in categorical_cols if c not in ["customer_ID", "S_2"]]
    numerical_cols = [c for c in numerical_cols if c not in ["customer_ID", "S_2"]]

    
    num_agg = data.groupby("customer_ID")[numerical_cols].agg(['mean', 'std', 'min', 'max', 'last'])
    num_agg.columns = ['_'.join(x) for x in num_agg.columns]

    catg_agg = data.groupby('customer_ID')[categorical_cols].agg(['count', 'last', 'nunique'])
    catg_agg.columns = ['_'.join(x) for x in catg_agg.columns]

    temp = pd.concat([num_agg, catg_agg], axis=1)
    del num_agg
    del catg_agg
    gc.collect()

    return temp

# %%
agg_df = aggregate_features(train, catg, cont_features)
agg_df.to_csv("aggregated_data.csv")
agg_df
# Out:
#                                                     B_1_mean   B_1_std  \
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  0.012009  0.006546
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...  0.025650  0.027750
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...  0.004387  0.002786
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...  0.059875  0.080538
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...  0.005939  0.002475
# ...                                                      ...       ...
# ffff41c8a52833b56430603969b9ca48d208e7c192c6a40...  0.029175  0.014286
# ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fdd...  0.368408  0.051249
# ffff9984b999fccb2b6127635ed0736dda94e544e67e026...  0.043030  0.040382
# ffffa5c46bc8de74f5a4554e74e239c8dee6b9baf388145...  0.018158  0.009637
# fffff1d38b785cef84adeace64f8f83db3a0c31e8d92eab...  0.037964  0.034429
#
#                                                      B_1_min   B_1_max  \
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  0.001930  0.021652
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...  0.006710  0.109619
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...  0.001472  0.009995
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...  0.005909  0.280029
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...  0.000776  0.009804
# ...                                                      ...       ...
# ffff41c8a52833b56430603969b9ca48d208e7c192c6a40...  0.006084  0.051941
# ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fdd...  0.292480  0.452148
# ffff9984b999fccb2b6127635ed0736dda94e544e67e026...  0.013000  0.162476
# ffffa5c46bc8de74f5a4554e74e239c8dee6b9baf388145...  0.000281  0.030563
# fffff1d38b785cef84adeace64f8f83db3a0c31e8d92eab...  0.000077  0.119507
#
#                                                     B_1_last  B_10_mean  \
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  0.009384   0.270264
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...  0.034698   0.298828
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...  0.004284   0.273682
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...  0.012566   0.306641
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...  0.007679   0.100342
# ...                                                      ...        ...
# ffff41c8a52833b56430603969b9ca48d208e7c192c6a40...  0.028519   0.591309
# ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fdd...  0.292480   0.042603
# ffff9984b999fccb2b6127635ed0736dda94e544e67e026...  0.020569   0.268555
# ffffa5c46bc8de74f5a4554e74e239c8dee6b9baf388145...  0.015839   0.039734
# fffff1d38b785cef84adeace64f8f83db3a0c31e8d92eab...  0.000077   0.256592
#
#                                                     B_10_std  B_10_min  \
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  0.181835  0.096191
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...  0.003044  0.293945
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...  0.052867  0.162109
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...  0.079525  0.192993
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...  0.074579  0.044739
# ...                                                      ...       ...
# ffff41c8a52833b56430603969b9ca48d208e7c192c6a40...  0.373031  0.366211
# ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fdd...  0.016051  0.021011
# ffff9984b999fccb2b6127635ed0736dda94e544e67e026...  0.069366  0.092590
# ffffa5c46bc8de74f5a4554e74e239c8dee6b9baf388145...  0.041169  0.006924
# fffff1d38b785cef84adeace64f8f83db3a0c31e8d92eab...  0.202081  0.107117
#
#                                                     B_10_max  B_10_last  ...  \
# customer_ID                                                              ...
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  0.741699   0.326172  ...
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...  0.302734   0.297119  ...
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...  0.302734   0.296387  ...
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...  0.431885   0.411621  ...
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...  0.260742   0.125244  ...
# ...                                                      ...        ...  ...
# ffff41c8a52833b56430603969b9ca48d208e7c192c6a40...  1.417969   0.436035  ...
# ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fdd...  0.083557   0.021011  ...
# ffff9984b999fccb2b6127635ed0736dda94e544e67e026...  0.302734   0.302734  ...
# ffffa5c46bc8de74f5a4554e74e239c8dee6b9baf388145...  0.154907   0.035461  ...
# fffff1d38b785cef84adeace64f8f83db3a0c31e8d92eab...  0.891602   0.291260  ...
#
#                                                     D_63_nunique  D_64_count  \
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...             1          13
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...             1          13
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...             1          13
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...             1          13
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...             1          13
# ...                                                          ...         ...
# ffff41c8a52833b56430603969b9ca48d208e7c192c6a40...             1          13
# ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fdd...             1          13
# ffff9984b999fccb2b6127635ed0736dda94e544e67e026...             1          13
# ffffa5c46bc8de74f5a4554e74e239c8dee6b9baf388145...             1          13
# fffff1d38b785cef84adeace64f8f83db3a0c31e8d92eab...             1          13
#
#                                                     D_64_last  D_64_nunique  \
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...          O             1
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...          O             1
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...          R             1
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...          O             1
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...          O             1
# ...                                                       ...           ...
# ffff41c8a52833b56430603969b9ca48d208e7c192c6a40...          U             1
# ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fdd...          R             1
# ffff9984b999fccb2b6127635ed0736dda94e544e67e026...          U             1
# ffffa5c46bc8de74f5a4554e74e239c8dee6b9baf388145...          U             2
# fffff1d38b785cef84adeace64f8f83db3a0c31e8d92eab...          O             2
#
#                                                     D_66_count  D_66_last  \
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...           0        NaN
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...           0        NaN
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...           0        NaN
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...           0        NaN
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...          13        1.0
# ...                                                        ...        ...
# ffff41c8a52833b56430603969b9ca48d208e7c192c6a40...          13        1.0
# ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fdd...           0        NaN
# ffff9984b999fccb2b6127635ed0736dda94e544e67e026...           0        NaN
# ffffa5c46bc8de74f5a4554e74e239c8dee6b9baf388145...           0        NaN
# fffff1d38b785cef84adeace64f8f83db3a0c31e8d92eab...           0        NaN
#
#                                                     D_66_nunique  D_68_count  \
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...             0          13
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...             0          13
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...             0          13
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...             0          13
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...             1          13
# ...                                                          ...         ...
# ffff41c8a52833b56430603969b9ca48d208e7c192c6a40...             1          13
# ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fdd...             0          13
# ffff9984b999fccb2b6127635ed0736dda94e544e67e026...             0          13
# ffffa5c46bc8de74f5a4554e74e239c8dee6b9baf388145...             0          13
# fffff1d38b785cef84adeace64f8f83db3a0c31e8d92eab...             0          13
#
#                                                     D_68_last  D_68_nunique
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...        6.0             1
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...        6.0             1
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...        6.0             1
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...        3.0             3
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...        6.0             1
# ...                                                       ...           ...
# ffff41c8a52833b56430603969b9ca48d208e7c192c6a40...        6.0             1
# ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fdd...        6.0             1
# ffff9984b999fccb2b6127635ed0736dda94e544e67e026...        5.0             1
# ffffa5c46bc8de74f5a4554e74e239c8dee6b9baf388145...        3.0             2
# fffff1d38b785cef84adeace64f8f83db3a0c31e8d92eab...        5.0             2
#
# [458913 rows x 916 columns]
